# %%
import pandas as pd
import numpy as np

# %%
good_materials = np.array(
    ['38-1486-03',
     '38-1485-03',
     '38-1482-03',
     '38-1244-02',
     '38-1237-02',
     '38-1234-02',
     '38-1231-02',
     '38-1228-02',
     '38-1223-02',
     '38-1219-02',
     '38-1217-02'])

# %%
df = pd.DataFrame(good_materials)

# %%
df.to_csv('df_good_materials.csv')
