# %%
import pandas as pd
import numpy as np
import Trying_to_read_csv

# %%
df_good_materials = pd.read_csv('df_good_materials.csv')

# %%
np.array(df_good_materials['0'])
# Out:
# array(['38-1486-03', '38-1485-03', '38-1482-03', '38-1244-02',
#        '38-1237-02', '38-1234-02', '38-1231-02', '38-1228-02',
#        '38-1223-02', '38-1219-02', '38-1217-02'], dtype=object)

# %%
df_materials = Trying_to_read_csv.try_to_read_csv(path, 'cp1251', 'utf8')
