# %%
import read_data
import pandas as pd
import get_cat_name
import os
import Trying_to_read_csv
from DRAW_G import Plotter
import numpy as np
import Lin_analys

# %%
dir_name_with_data = 'ВЖМ4_ДП_011_111_Files'

# %%
Array_catalogs = get_cat_name.get_name_catalog(dir_name_with_data)
Array_catalogs.pop(0)
# Out:
# '.ipynb_checkpoints'

# %%
df_good_materials = pd.read_csv('df_good_materials.csv')

# %%
for catalog in Array_catalogs:
    
    if catalog in np.array(df_good_materials['0']):
    
        path = os.path.join(dir_name_with_data, catalog, 'Test file 1', f'{catalog}.csv')

        df = Trying_to_read_csv.try_to_read_csv(path, 'cp1251', 'utf8')
        
        print(df.shape[0])
    
        
        analyzer = Lin_analys.LinearInterval(np.array(df['Время, ч']), np.array(df['Деформация, %']), interval_for_check=5)
        analyzer.get_r2_score_array()
        analyzer.get_best_segment()
        
        print(f"X_start={analyzer.get_best_segment()[0]}, Y_start={analyzer.get_best_segment()[1]},  X_end={analyzer.get_best_segment()[2]}, Y_end={analyzer.get_best_segment()[3]}")

        
        
        #plotter = Plotter(x=df['Время, ч'], y=df['Деформация, %'],
                     #     color = 'blue', title = 'Образец ' + catalog,
                        #  x_label = 'Время, ч', y_label = 'Деформация, %')
       # plotter.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 9
#       5 path = os.path.join(dir_name_with_data, catalog, 'Test file 1', f'{catalog}.csv')
#       7 df = Trying_to_read_csv.try_to_read_csv(path, 'cp1251', 'utf8')
# ----> 9 print(len(df[0]))
#      12 analyzer = Lin_analys.LinearInterval(np.array(df['Время, ч']), np.array(df['Деформация, %']), interval_for_check=5)
#      13 analyzer.get_r2_score_array()
#
# File D:\anaconda\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\anaconda\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0
