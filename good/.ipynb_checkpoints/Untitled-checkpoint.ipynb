# %%
from excel_to_bd import excel_to_bd_main
from all_experiments_graphs import all_experiments_main

# %%
excel_to_bd_main()
# Out:
# Подключение к базе данных PostgreSQL прошло успешно!
# Данные из Excel успешно загружены:
#      Material  Temperature  Orientation  Time lapse  Deformation  Tension
# 0  38-0669-03          850          111         0.0          0.0    715.4
# 1  38-0669-03          850          111         0.0          0.0    715.4
# 2  38-0669-03          850          111         0.0          0.0    715.4
# 3  38-0669-03          850          111         0.0          0.0    715.4
# 4  38-0669-03          850          111         0.0          0.0    715.4
# Данные успешно перенесены в таблицу experiment_full_table базы данных tanya_experiment!
# Подключение к базе данных закрыто.
# Данные из Excel успешно загружены:
#      Material  Beginning    End
# 0  38-1486-03       20.0   90.0
# 1  38-1485-03       50.0  140.0
# 2  38-1482-03      150.0  720.0
# 3  38-1457-03       25.0   60.0
# 4  38-1456-03      300.0  740.0
# Данные успешно перенесены в таблицу lengths базы данных tanya_experiment!
# ...

# %%
all_experiments_main()

# %%
from de_dt_materials import de_dt_materials_main

# %%
de_dt_materials_main()
# Out:
# Таблица temp_850_orient_111 успешно создана и заполнена!
# Таблица temp_750_orient_11 успешно создана и заполнена!
# Таблица temp_850_orient_11 успешно создана и заполнена!
# Таблица temp_950_orient_11 успешно создана и заполнена!
# Таблица temp_1050_orient_11 успешно создана и заполнена!
# Таблица temp_1150_orient_11 успешно создана и заполнена!
# Таблица temp_750_orient_111 успешно создана и заполнена!
# Таблица temp_950_orient_111 успешно создана и заполнена!

# %%
from A_n_results_LinReg import find_constants

# %%
find_constants()
# Out:
# В таблице temp_750_orient_11 нет подходящих данных (Tension и dE_dt должны быть > 0).
# Результаты успешно записаны в таблицу constants_table!
